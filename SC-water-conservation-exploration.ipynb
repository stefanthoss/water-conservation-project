# %% [markdown]
# # Water Conservation Exploration
# https://www.kaggle.com/calepa/water-conservation-supplier-compliance

# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Data Loading

# %%
# Loading the list of non-filers for July 2016
nf_jul = pd.read_csv('july_2016_nonfilers.csv', sep=';')
nf_jul.head()
# Out:
#   July 2016 Non-filers (The following suppliers did not submit July 2016 data by September 19, 2016)
# 0                                Cloverdale  City of
# 1                                   Lemoore  City of
# 2                               Porterville  City of
# 3                                     Ukiah  City of

# %%
# Loading the list of non-filers for August 2016
nf_aug = pd.read_csv('august_2016_nonfilers.csv', sep=';')
nf_aug.head()
# Out:
#   August 2016 Non-filers (The following suppliers did not submit July 2016 data by September 19, 2016)
# 0                                   Anderson City of
# 1                                  Calexico  City of
# 2                                 Cloverdale City of
# 3                                 Escondido  City of
# 4                           Hi-Desert Water District

# %%
# Loading the dataset for supplier compliance and print the columns
sc = pd.read_csv('supplier_compliance.csv', skipinitialspace=True)
sc.columns
# Out:
# Index([u'Supplier Name', u'Hydrologic Region',
#        u'State-mandated Conservation Standard - Previous (3/1/2016)',
#        u'State-mandated Conservation Standard - Current (Effective 6/1/2016)',
#        u'Did Supplier Self-certify?',
#        u'Enforceable Cumulative Percent Savings (as compared to 2013) - June 2015-Aug 2016',
#        u'June 2016 to Aug 2016 Self-certified?',
#        u'Applicable Cumulative Savings by Supplier (as compared to 2013)',
#        u'Missed Conservation Standard By', u'Order Status',
#        u'Monthly Savings (as compared to 2013) - Aug 2015',
#        u'Monthly Savings (as compared to 2013) - Aug 2016',
#        u'Estimated Aug 2016 Monthly R-GPCD', u'Total Population Served'],
#       dtype='object')

# %%
# Initial look at the dataset
sc.head()
# Out:
#                    Supplier Name Hydrologic Region  \
# 0       California City  City of    South Lahontan
# 1  Yucaipa Valley Water District       South Coast
# 2                Sanger  City of       Tulare Lake
# 3               Adelanto City of    South Lahontan
# 4             Red Bluff  City of  Sacramento River
#
#   State-mandated Conservation Standard - Previous (3/1/2016)  \
# 0                                                28%
# 1                                                34%
# 2                                                26%
# 3                                                16%
# 4                                                33%
#
#   State-mandated Conservation Standard - Current (Effective 6/1/2016)  \
# 0                                                28%
# 1                                                20%
# 2                                                26%
# 3                                                16%
# 4                                                33%
#
#   Did Supplier Self-certify?  \
# 0                         No
# 1                        Yes
# 2                         No
# 3                         No
# 4                         No
#
#   Enforceable Cumulative Percent Savings (as compared to 2013) - June 2015-Aug 2016  \
# 0                                              13.1%
# 1                                              18.3%
# 2                                              17.3%
# 3                                               9.3%
# 4                                              27.8%
#
#   June 2016 to Aug 2016 Self-certified?  \
# 0                                 18.0%
# 1                                  7.1%
# 2                                 12.4%
# 3                                -10.3%
# 4                                 19.5%
#
#   Applicable Cumulative Savings by Supplier (as compared to 2013)  \
# 0                                              13.1%
# 1                                               7.1%
# 2                                              17.3%
# 3                                               9.3%
# 4                                              27.8%
#
#   Missed Conservation Standard By Order Status  \
# 0                           14.9%            C
# 1                           12.9%          NaN
# 2                            8.7%          NaN
# 3                            6.7%            C
# 4                            5.2%          NaN
#
#   Monthly Savings (as compared to 2013) - Aug 2015  \
# 0                                            16.8%
# 1                                            26.4%
# 2                                            38.0%
# 3                                            20.5%
# 4                                            42.4%
#
#   Monthly Savings (as compared to 2013) - Aug 2016  \
# 0                                            20.5%
# 1                                            11.9%
# 2                                            17.2%
# 3                                           -30.6%
# 4                                            30.8%
#
#    Estimated Aug 2016 Monthly R-GPCD Total Population Served
# 0                              148.5                  14,120
# 1                              260.0                  45,018
# 2                              181.1                  25,664
# 3                              125.5                  29,023
# 4                              202.9                  14,076

# %%
# Convert the string columns with percentage values to float columns and check the data types of all columns
sc.iloc[:,[2,3,5,6,7,8,10,11]] = sc.iloc[:,[2,3,5,6,7,8,10,11]].replace('%','',regex=True).apply(pd.to_numeric)/100
sc.iloc[:,13] = sc.iloc[:,13].replace(',','',regex=True).apply(pd.to_numeric)
sc.dtypes
# Out:
# Supplier Name                                                                         object
# Hydrologic Region                                                                     object
# State-mandated Conservation Standard - Previous (3/1/2016)                           float64
# State-mandated Conservation Standard - Current (Effective 6/1/2016)                  float64
# Did Supplier Self-certify?                                                            object
# Enforceable Cumulative Percent Savings (as compared to 2013) - June 2015-Aug 2016    float64
# June 2016 to Aug 2016 Self-certified?                                                float64
# Applicable Cumulative Savings by Supplier (as compared to 2013)                      float64
# Missed Conservation Standard By                                                      float64
# Order Status                                                                          object
# Monthly Savings (as compared to 2013) - Aug 2015                                     float64
# Monthly Savings (as compared to 2013) - Aug 2016                                     float64
# Estimated Aug 2016 Monthly R-GPCD                                                    float64
# Total Population Served                                                                int64
# dtype: object

# %%
# Check the prepared dataset
sc.head()
# Out:
#                    Supplier Name Hydrologic Region  \
# 0       California City  City of    South Lahontan
# 1  Yucaipa Valley Water District       South Coast
# 2                Sanger  City of       Tulare Lake
# 3               Adelanto City of    South Lahontan
# 4             Red Bluff  City of  Sacramento River
#
#    State-mandated Conservation Standard - Previous (3/1/2016)  \
# 0                                               0.28
# 1                                               0.34
# 2                                               0.26
# 3                                               0.16
# 4                                               0.33
#
#    State-mandated Conservation Standard - Current (Effective 6/1/2016)  \
# 0                                               0.28
# 1                                               0.20
# 2                                               0.26
# 3                                               0.16
# 4                                               0.33
#
#   Did Supplier Self-certify?  \
# 0                         No
# 1                        Yes
# 2                         No
# 3                         No
# 4                         No
#
#    Enforceable Cumulative Percent Savings (as compared to 2013) - June 2015-Aug 2016  \
# 0                                              0.131
# 1                                              0.183
# 2                                              0.173
# 3                                              0.093
# 4                                              0.278
#
#    June 2016 to Aug 2016 Self-certified?  \
# 0                                  0.180
# 1                                  0.071
# 2                                  0.124
# 3                                 -0.103
# 4                                  0.195
#
#    Applicable Cumulative Savings by Supplier (as compared to 2013)  \
# 0                                              0.131
# 1                                              0.071
# 2                                              0.173
# 3                                              0.093
# 4                                              0.278
#
#    Missed Conservation Standard By Order Status  \
# 0                            0.149            C
# 1                            0.129          NaN
# 2                            0.087          NaN
# 3                            0.067            C
# 4                            0.052          NaN
#
#    Monthly Savings (as compared to 2013) - Aug 2015  \
# 0                                             0.168
# 1                                             0.264
# 2                                             0.380
# 3                                             0.205
# 4                                             0.424
#
#    Monthly Savings (as compared to 2013) - Aug 2016  \
# 0                                             0.205
# 1                                             0.119
# 2                                             0.172
# 3                                            -0.306
# 4                                             0.308
#
#    Estimated Aug 2016 Monthly R-GPCD  Total Population Served
# 0                              148.5                    14120
# 1                              260.0                    45018
# 2                              181.1                    25664
# 3                              125.5                    29023
# 4                              202.9                    14076

# %%
# Basic statistics about the dataset
sc.describe(include = 'all')
# Out:
#                                    Supplier Name Hydrologic Region  \
# count                                        389               389
# unique                                       389                10
# top     Elsinore Valley Municipal Water District       South Coast
# freq                                           1               171
# mean                                         NaN               NaN
# std                                          NaN               NaN
# min                                          NaN               NaN
# 25%                                          NaN               NaN
# 50%                                          NaN               NaN
# 75%                                          NaN               NaN
# max                                          NaN               NaN
#
#         State-mandated Conservation Standard - Previous (3/1/2016)  \
# count                                          389.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                             0.217609
# std                                              0.079607
# min                                              0.040000
# 25%                                              0.160000
# 50%                                              0.220000
# 75%                                              0.280000
# max                                              0.360000
#
#         State-mandated Conservation Standard - Current (Effective 6/1/2016)  \
# count                                          389.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                             0.023136
# std                                              0.063861
# min                                              0.000000
# 25%                                              0.000000
# 50%                                              0.000000
# 75%                                              0.000000
# max                                              0.340000
#
#        Did Supplier Self-certify?  \
# count                         389
# unique                          2
# top                           Yes
# freq                          361
# mean                          NaN
# std                           NaN
# min                           NaN
# 25%                           NaN
# 50%                           NaN
# 75%                           NaN
# max                           NaN
#
#         Enforceable Cumulative Percent Savings (as compared to 2013) - June 2015-Aug 2016  \
# count                                          389.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                             0.242018
# std                                              0.068435
# min                                              0.046000
# 25%                                              0.199000
# 50%                                              0.239000
# 75%                                              0.281000
# max                                              0.484000
#
#         June 2016 to Aug 2016 Self-certified?  \
# count                              389.000000
# unique                                    NaN
# top                                       NaN
# freq                                      NaN
# mean                                 0.202856
# std                                  0.071208
# min                                 -0.103000
# 25%                                  0.159000
# 50%                                  0.201000
# 75%                                  0.241000
# max                                  0.479000
#
#         Applicable Cumulative Savings by Supplier (as compared to 2013)  \
# count                                          389.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                             0.204820
# std                                              0.070885
# min                                             -0.029000
# 25%                                              0.160000
# 50%                                              0.203000
# 75%                                              0.243000
# max                                              0.481000
#
#         Missed Conservation Standard By Order Status  \
# count                        389.000000            7
# unique                              NaN            2
# top                                 NaN            A
# freq                                NaN            4
# mean                          -0.181684          NaN
# std                            0.082255          NaN
# min                           -0.479000          NaN
# 25%                           -0.227000          NaN
# 50%                           -0.188000          NaN
# 75%                           -0.144000          NaN
# max                            0.149000          NaN
#
#         Monthly Savings (as compared to 2013) - Aug 2015  \
# count                                         389.000000
# unique                                               NaN
# top                                                  NaN
# freq                                                 NaN
# mean                                            0.270414
# std                                             0.089001
# min                                            -0.174000
# 25%                                             0.217000
# 50%                                             0.274000
# 75%                                             0.326000
# max                                             0.556000
#
#         Monthly Savings (as compared to 2013) - Aug 2016  \
# count                                         389.000000
# unique                                               NaN
# top                                                  NaN
# freq                                                 NaN
# mean                                            0.180591
# std                                             0.083947
# min                                            -0.306000
# 25%                                             0.137000
# 50%                                             0.180000
# 75%                                             0.223000
# max                                             0.459000
#
#         Estimated Aug 2016 Monthly R-GPCD  Total Population Served
# count                          389.000000             3.890000e+02
# unique                                NaN                      NaN
# top                                   NaN                      NaN
# freq                                  NaN                      NaN
# mean                           133.831877             9.065885e+04
# std                             68.239474             2.434458e+05
# min                             35.400000             1.120000e+02
# 25%                             87.000000             2.049900e+04
# 50%                            118.300000             4.376700e+04
# 75%                            164.500000             9.120700e+04
# max                            524.600000             4.061504e+06

# %% [markdown]
# ## Exploration

# %%
# Boxplots about how much the conservation standard was missed for each hydrologic region
sns.boxplot(x='Missed Conservation Standard By', y='Hydrologic Region', data=sc, whis=np.inf)

# %%
# Find the largest suppliers
sc.sort_values('Total Population Served', ascending=False).loc[:,['Supplier Name', 'Total Population Served']].head()
# Out:
#                                  Supplier Name  Total Population Served
# 91   Los Angeles Department of Water and Power                  4061504
# 170      East Bay Municipal Utilities District                  1400000
# 107                         San Diego  City of                  1339958
# 338                     San Jose Water Company                   990000
# 69   San Francisco Public Utilities Commission                   859276
